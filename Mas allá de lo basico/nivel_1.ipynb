# %% [markdown]
# ### Función lambda
#
# Es una función anónima (sin nombre) que puedes definir en una sola línea.
# Se usa cuando necesitas una función pequeña y temporal.
#
# lambda argumentos: expresión

# %%
# Creación de una funcion normal 
def cuadrado(x):
    return x**2

# Con lambda
cuadrado_lambda = lambda x: x**2

cuadrado(6), cuadrado_lambda(6)
# Out:
# (36, 36)

# %%
# Con varios parametros 
suma = lambda a,b: a + b
suma(3,5)
# Out:
# 8

# %%
def aplicar(func, valor):
    return func(valor)

print(aplicar(lambda x: x ** 3, 2))  # → 8
# Out:
# 8

# %%
# Ejercicos elevar un numero al cuadrado 

cuadrado = lambda x: x ** 2
print(cuadrado(8))
# Out:
# 64

# %%
# Obtener el ultimo caracter de una palabra 

ultimo_caracter = lambda s: s[-1]

ultima_letra = ultimo_caracter("python")
ultima_letra
# Out:
# 'n'

# %%
# Numero mayor entre dos numeros 

max = lambda a,b: a if a>b else b
print(max(10,20))
# Out:
# 20

# %%
# Comprobar si un numero es par o impar
par = lambda x: True if x % 2 == 0 else False 
print(par(3))
# Out:
# False

# %%
# Longitud de una cadena 
lon = lambda s: len(s)

print(lon("Juan Gabriel Carvajal Negrete"))
# Out:
# 29

# %%
# Primer cacter de una cadena
pri = lambda s: s[0]

print(pri("Juan Gabriel Carvajal Negrete"))
# Out:
# J

# %%
# Sumar tres numeros
sum = lambda a,b,c: a + b + c

print(sum(2,3,4))
# Out:
# 9

# %%
# Ordenar una lista por el ultimmo carcater 

order = lambda lista: sorted(lista,key=lambda x: x[-1]) 

print(order(['juan','pedro','ana','carlos']))
# Out:
# ['ana', 'juan', 'pedro', 'carlos']

# %%
# Ordenar una lista de tuplas por el segundo elemento
lista_tuplas = [(1, 3), (2, 1), (4, 2)]
ordenada = lambda lista: sorted(lista_tuplas, key=lambda x: x[1])
print(ordenada(lista_tuplas))
# Out:
# [(2, 1), (4, 2), (1, 3)]

# %%
# convertir grados celsius a fahrenheit
conver = lambda c: c*1.8 + 32
print(conver(30))
# Out:
# 86.0

# %%
# Precio mas iva 
iva = lambda precio: precio*1.19
print(iva(10000))
# Out:
# 11900.0

# %%
# identifica di una palabra termina en vocal
voc = lambda s: True if s[-1] in 'aeiou' else False
print(voc("tarde"))
# Out:
# True

# %% [markdown]
# ### Uso de la funcion map

# %%
# Aplica una función a cada elemento de un iterable 

numeros = [1, 2, 3, 4, 5]
dobles = map(lambda x: x * 2, numeros)
print(list(dobles))
# Out:
# [2, 4, 6, 8, 10]

# %%
# Ejemplo con varias listas 
a = [1, 2, 3]
b = [4, 5, 6]
suma = map(lambda x, y: x + y, a, b)
print(list(suma))
# Out:
# [5, 7, 9]

# %%
# Ejemplos con string 
nombres = ["juan", "maria", "pedro"]
mayus = map(str.capitalize, nombres)
print(list(mayus))
# Out:
# ['Juan', 'Maria', 'Pedro']

# %%
# Ejercicios practicos 

# 1 Multiplicar cada numero por dos 

l1 = [2,6,8,4,5]

l2 = map(lambda x: x*2,l1)
list(l2)
# Out:
# [4, 12, 16, 8, 10]

# %%
# 2 Convertir cada palabra a lista 
l1 = ["juan", "carvajal", "python"]
l2 =  map(list,l1)
list(l2)
# Out:
# [['j', 'u', 'a', 'n'],
#  ['c', 'a', 'r', 'v', 'a', 'j', 'a', 'l'],
#  ['p', 'y', 't', 'h', 'o', 'n']]

# %%
# 3 Convertir cada numero a string 
l1 = [1,3,6,3]
l2 = map(str,l1)
list(l2)
# Out:
# ['1', '3', '6', '3']

# %%
# 4 Elevar cada numero al cuadrado 
l1 = [2,6,8,4,5]
l2 = map(lambda x: x**2,l1)
list(l2)
# Out:
# [4, 36, 64, 16, 25]

# %%
# 5 obtener la longitud de cada palabra 
l1 = ["hola", "python", "map"]
l2 = map(len,l1)
list(l2)
# Out:
# [4, 6, 3]

# %%
list("juan")
# Out:
# ['j', 'u', 'a', 'n']

# %%
# 6 obener la primera letra de cada strng
l1 = ["Sol", "Luna", "Estrella"]
l2 = map(lambda s: s[0],l1)
list(l2)
# Out:
# ['S', 'L', 'E']

# %%
# Convertir a temperatura 
l1 = [0, 20, 30]
l2 = map(lambda x: x*1.8+32,l1)
list(l2)
# Out:
# [32.0, 68.0, 86.0]

# %%
# Sumar dos lista elemento a elemento
l1 = [1, 2, 3]
l2 = [4, 5, 6]

l3 = list(map(lambda x,y: x+y,l1,l2))
l3
# Out:
# [5, 7, 9]

# %%
# Multiplicar dos listas elemento a elemento 
l1 = [1, 2, 3]
l2 = [4, 5, 6]

l3 = list(map(lambda x,y: x*y,l1,l2))
l3
# Out:
# [4, 10, 18]

# %%
# Extarer solo el domino de un correo
l1 = ["juan@gmail.com", "maria@hotmail.com", "pedro@outlook.com"]
l2 = map(lambda s: s.split('@')[1],l1)
list(l2)
# Out:
# ['gmail.com', 'hotmail.com', 'outlook.com']

# %%
# Limpiar espacios en una lista de string
l1 = ["  hola ", " python  ", "  mundo"]
l2 = map(lambda s: s.replace(" ",""),l1)
list(l2)
# Out:
# ['hola', 'python', 'mundo']

# %%
# calcular el precio final de cada producto

l1 = [10000, 20000, 35000]
l2 = map(lambda x: int(x+x*0.19), l1)
list(l2)
# Out:
# [11900, 23800, 41650]

# %%
# Convertir fecha de string a formato datetime 
from datetime import datetime
l1 =["2024-01-01", "2024-02-15"]
l2 = map(lambda x:datetime.strptime(x,"%Y-%m-%d"),l1)
list(l2)
# Out:
# [datetime.datetime(2024, 1, 1, 0, 0), datetime.datetime(2024, 2, 15, 0, 0)]

# %%
# transformar una lista de nombres auxiliares 
l1 = ["Juan Carvajal", "Ana Torres", "Pedro Gómez"]
# l2 = map(lambda n: f"{n.split()[0][0]}.{n.split()[1][0]}.",l1)
l2 = map(lambda n: '.'.join(p[0] for p in n.split()) + '.', l1)
list(l2)
# Out:
# ['J.C.', 'A.T.', 'P.G.']

# %%
l = [1,4,6,5,8,10,12]
l = map(lambda x: x if x%2 == 0 else None, l)
list(l)
# Out:
# [None, 4, 6, None, 8, 10, 12]

# %% [markdown]
# ### Función filter
#
# filter() filtra los elementos de un iterable que cumplan una condición (la función debe devolver True o False).

# %%
# Ejemlo basico
numeros = [1, 2, 3, 4, 5, 6]
pares = filter(lambda x: x % 2 == 0, numeros)
print(list(pares))  # → [2, 4, 6]
# Out:
# [2, 4, 6]

# %%
palabras = ["sol", "luna", "estrella", "cielo"]
largas = filter(lambda palabra: len(palabra) > 4, palabras)
print(list(largas))
# Out:
# ['estrella', 'cielo']

# %%
# Ejemplos 
# Filtrar numeros mayores a 10 
l1 = [5, 11, 20, 3, 15]
l2 = filter(lambda x: x > 10,l1)
list(l2)
# Out:
# [11, 20, 15]

# %%
# Palabras con mas de cuatro letras
l1 = ["sol", "luna", "estrella", "mar"]
l2 = filter(lambda x: len(x)>=4,l1)
list(l2)
# Out:
# ['luna', 'estrella']

# %%
# Filtrar palabras que empiecen con vocal

l1 = ["hola", "agua", "oso", "python", "uva"]
l2 = filter(lambda p: p[0] in "aeiou",l1)
list(l2)
# Out:
# ['agua', 'oso', 'uva']

# %%
# Filtrar numeros negrativos
l1 = [3, -1, 5, -6, 0, -2]
l2 = filter(lambda x: x<0,l1)
list(l2)
# Out:
# [-1, -6, -2]

# %%
#  Filtrar string que contengan la letra a
l1 = ["python", "java", "javascript", "c++"]
l2 = filter(lambda x: "a" in x,l1)
list(l2)
# Out:
# ['java', 'javascript']

# %%
# Filtrar solo valores Booleanos True
l1 = [True, False, True, False, True]
l2 = filter(lambda b: b == True,l1)
list(l2)
# Out:
# [True, True, True]

# %%
# filtrar numeros cuyos cuadrados sean mayor de 50
l1 = [5, 6, 7, 8, 3]
l2 = filter(lambda x: x**2 > 50,l1)
list(l2)
# Out:
# [8]

# %%
# Filtrar correos que sean gmail
L1 = ["juan@gmail.com", "ana@hotmail.com", "luis@gmail.com"]
l2 = filter(lambda s: "gmail" in s,L1)
list(l2)
# Out:
# ['juan@gmail.com', 'luis@gmail.com']

# %%
# Filtrar tuplas donde el segundo valor sea mayor que 10
l1 = [(1, 5), (2, 20), (3, 15), (4, 7)]
l2 = filter(lambda t: t[1]>10,l1)
list(l2)
# Out:
# [(2, 20), (3, 15)]

# %%
# Filtrar palabras que terminen en vocal 
l1 = ["perro", "sol", "casa", "flor", "uva"]
l2 = filter(lambda s: s[-1] in "aeiou",l1)
list(l2)
# Out:
# ['perro', 'casa', 'uva']

# %%
# Filtrar fechas que sean del año 2024
l1 = ["2023-12-01", "2024-01-05", "2024-09-30", "2022-03-10"]
l2 = filter(lambda f: "2024" in f,l1)
list(l2)
# Out:
# ['2024-01-05', '2024-09-30']

# %% [markdown]
# ### Función reduce
# reduce() reduce un iterable a un solo valor, aplicando una función acumuladora.
# 👉 A diferencia de map() y filter(), no es una función incorporada, sino que está en el módulo functools.

# %%
from functools import reduce
numeros = [1, 2, 3, 4, 5]
producto = reduce(lambda x, y: x * y, numeros)
print(producto)  # → 120
# Out:
# 120

# %%
palabras = ["Hola", "mundo", "Python"]
frase = reduce(lambda x, y: x + " " + y, palabras)
print(frase)  # → "Hola mundo Python"
# Out:
# Hola mundo Python

# %% [markdown]
# ### Comprensiones en Python - Listas
#
# Las comprensiones son una forma concisa y elegante de crear listas, diccionarios y conjuntos a partir de iterables

# %%
#Sintaxis basica 
# [nueva_expr for variable in iterable]
nums = [1, 2, 3, 4,6,8,10,12,23,15]
cuadrados = [n**2 for n in nums]
# Cuadrados de cada elemento de la lista, este enfoque puede ser mas legible y conciso que usar una funcón map y filter con un función lambda.

# Con map y lambda 
numsml = list(map(lambda x: x**2,nums))
numsml
numsml1 = list(filter(lambda x: x%2 == 0,nums))
print(numsml1)
numlc = [x for x in nums if x%2 == 0]
numlc
# Out:
# [2, 4, 6, 8, 10, 12]
# [2, 4, 6, 8, 10, 12]

# %% [markdown]
# ### Comprensiones en Python - Diccionarios

# %%
# Sintaxis 
# {clave: valor for variable in iterable}
cuadrados = {n: n**2 for n in range(10)}
cuadrados
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# ### Ingenieria de datos, Analisis de datos, Modelado de datos, Transfromación de datos con Python.
